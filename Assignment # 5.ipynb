# %%
#Question No.1
def factorial(n):
    if n==0:
        return 1
    else:
        fac=n*factorial(n-1)
        return fac
n=int(input("Enter Number here : "))
print("____________________________")
print("You Enter "+str(n)+"!")
fac=factorial(n)
print("Answer=",fac)
print("____________________________")
# Out:
# Enter Number here : 4
# ____________________________
# You Enter 4!
# Answer= 24
# ____________________________

# %%
#Question No.2
def string(s):
    a={"upper_case":0,"lower_case":0}
    for c in s:
        if c.isupper():
            a["upper_case"]+=1
        elif c.islower():
            a["lower_case"]+=1
        else:
            pass
    print("The String You Write :",s)
    print("Upper Case Characters in Strings",a["upper_case"])
    print("Lower Case Characters in Strings",a["lower_case"])
s=input("Enter String:")
string(s)
# Out:
# Enter String:This is Usman
# The String You Write : This is Usman
# Upper Case Characters in Strings 2
# Lower Case Characters in Strings 9

# %%
#Question No.3
def EvenOdd(n):
    num=[]
    for a in n:
        if a%2==0:
            num.append(a)
    return num
n=[]
b=int(input("Enter How Many You Randomly Enter Number in a list :"))
for i in range(0,b):
    c=int(input("Enter List :"))
    n.append(c)
print("Even Numbers in a List:",EvenOdd(n))
# Out:
# Enter How Many You Randomly Enter Number in a list :7
# Enter List :23
# Enter List :17
# Enter List :198
# Enter List :71
# Enter List :51
# Enter List :9
# Enter List :10
# Even Numbers in a List: [198, 10]

# %%
#Question No. 4
def palidrome(s):
    left_position=0
    right_position=len(s)-1
    while right_position>=left_position:
        if not(s[left_position]==s[right_position]):
            return False
        left_position+=1
        right_position-=1
    return True
s=input("Enter Palidrome:")
print(palidrome(s))
# Out:
# Enter Palidrome:tibit
# True

# %%
#Question No. 5
def prime(n):
    if n==1:
        return False
    elif n==2:
        return True
    else:
        if ((n%2)==0):
            return False
        return True
n=int(input("Enter Number:"))
print(prime(n))
# Out:
# Enter Number:97
# True

# %%
#Question No. 6
def isInteger(userinput):
    try:
        int(userinput)
        return True
    except ValueError:
        return False

    
def menuMenu(menu):
    print("\n________________\n Main Menu \n________________\n")
    for menuKey,menuName in menu.items():
        print("{}. {}".format(menuKey,menuName))
    userCommand=input("Enter Command :")
    return userCommand

def addTask(taskDictionary):
    print("\n________________\n Add Items \n________________\n")
    taskIndex=len(taskDictionary)+1
    taskName=input("Item #{}. ".format(taskIndex))
    taskDictionary.update({taskIndex : taskName})
    print("Item #{} - Successfully Added".format(taskIndex))
    
def viewTask(taskDictionary):
    print("\n________________\n Viewing Items \n________________\n")
    if len(taskDictionary) > 0:
        for taskIndex,taskname in taskDictionary.items():
            print("Item #{}. - {}".format(taskIndex,taskname))
    else:
        print("No Item Found\n")
        
def deletingTask(taskDictionary):
    print("\n________________\n Deleting Items \n________________\n")
    if len(taskDictionary) > 0:
        for taskIndex,taskname in taskDictionary.items():
            print("Item #{}. - {}".format(taskIndex,taskname))
        taskIndex=int(input("Enter Item Index eg. 1:"))
        if taskIndex in taskDictionary.keys():
            taskDictionary.pop(taskIndex)
            print("Item #{}. - Successfullt Deleted".format(taskIndex))
        else:
            print("Invalid Index,Try Valid Index")
    else:
        print("No Item Found\n")

menu={
    1:"Add Items",
    2:"View Items",
    3:"Delete Items",
    4:"EXIT"
}

taskDictionary={}
    
while (True):
    userCommand=menuMenu(menu)
    if isInteger(userCommand)==True:
        userCommand=int(userCommand)
        if userCommand > 0 and userCommand <=4:
            print("Command Accepted\n")
            if userCommand==1:
                addTask(taskDictionary)
            if userCommand==2:
                viewTask(taskDictionary)
            if userCommand==3:
                deletingTask(taskDictionary)
            if userCommand==4:
                print("App Terminated")
                break
        else:
            print("Invalid Command,Try Valid Command\n")
    else:
        print("Invalid Command,Try Valid Command\n")
# Out:
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :1
# Command Accepted
#
#
# ________________
#  Add Items
# ________________
#
# Item #1. Flour
# Item #1 - Successfully Added
#
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :Rice
# Invalid Command,Try Valid Command
#
#
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :1
# Command Accepted
#
#
# ________________
#  Add Items
# ________________
#
# Item #2. Rice
# Item #2 - Successfully Added
#
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :1
# Command Accepted
#
#
# ________________
#  Add Items
# ________________
#
# Item #3. Apples & Oranges
# Item #3 - Successfully Added
#
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :2
# Command Accepted
#
#
# ________________
#  Viewing Items
# ________________
#
# Item #1. - Flour
# Item #2. - Rice
# Item #3. - Apples & Oranges
#
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :1
# Command Accepted
#
#
# ________________
#  Add Items
# ________________
#
# Item #4. Wheat
# Item #4 - Successfully Added
#
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :1
# Command Accepted
#
#
# ________________
#  Add Items
# ________________
#
# Item #5. Sugar
# Item #5 - Successfully Added
#
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :2
# Command Accepted
#
#
# ________________
#  Viewing Items
# ________________
#
# Item #1. - Flour
# Item #2. - Rice
# Item #3. - Apples & Oranges
# Item #4. - Wheat
# Item #5. - Sugar
#
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :3
# Command Accepted
#
#
# ________________
#  Deleting Items
# ________________
#
# Item #1. - Flour
# Item #2. - Rice
# Item #3. - Apples & Oranges
# Item #4. - Wheat
# Item #5. - Sugar
# Enter Item Index eg. 1:4
# Item #4. - Successfullt Deleted
#
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :2
# Command Accepted
#
#
# ________________
#  Viewing Items
# ________________
#
# Item #1. - Flour
# Item #2. - Rice
# Item #3. - Apples & Oranges
# Item #5. - Sugar
#
# ________________
#  Main Menu
# ________________
#
# 1. Add Items
# 2. View Items
# 3. Delete Items
# 4. EXIT
# Enter Command :4
# Command Accepted
#
# App Terminated
